# %% [markdown]
# # Reconstruction error demo

# %%
# %config Completer.use_jedi = False

# %%
import os

os.chdir("..")

# %%
from deepsvg import utils
from deepsvg.svgtensor_dataset import load_dataset

import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cpu')

# %%
# prepare the data
from configs.deepsvg.hierarchical_ordered import Config
from torch.utils.data import DataLoader

cfg = Config()
cfg_modified = Config()
cfg_modified.model_args += ["commands_grouped", "args_grouped"]
dataset, _ = load_dataset(cfg_modified)
dataloader = DataLoader(
    dataset,
    batch_size=24,  #cfg.batch_size,
    shuffle=True,
    drop_last=True,
    num_workers=cfg.loader_num_workers,
    collate_fn=cfg.collate_fn,
)
# Out:
# Number of train SVGs: 23391
# First SVG in train:
# id                         5272
# platform                   ios7
# total_len                    37
# nb_groups                     4
# len_groups       [11, 5, 6, 15]
# max_len_group                15
# category                   baby
# subcategory                toys
# Name: 5272, dtype: object
#
# Number of test SVGs: 2599
# First SVG in test:
# id                    41146
# platform              win10
# total_len                24
# nb_groups                 3
# len_groups       [3, 18, 3]
# max_len_group            18
# category            network
# subcategory          clouds
# Name: 41146, dtype: object

# %%
pretrained_path = "./pretrained/hierarchical_ordered.pth.tar"
from configs.deepsvg.hierarchical_ordered import Config

cfg = Config()
cfg.print_params()
model = cfg.make_model().to(device)
utils.load_model(pretrained_path, model, device)
model.eval()
print("Model loaded")
# Out:
#   batch_size = 120
#   ckpt_every = 20
#   collate_fn = None
#   data_dir = ./dataset/icons_tensor/
#   dataloader_module = deepsvg.svgtensor_dataset
#   filter_category = None
#   filter_labels = None
#   filter_platform = None
#   filter_uni = None
#   grad_clip = 1.0
#   learning_rate = 0.002
#   loader_num_workers = 8
#   log_every = 20
#   loss_recon_fn_dict = {'loss_re': <function chamfer_loss at 0x7fcb782f2f80>}
#   max_num_groups = 8
#   max_seq_len = 30
#   max_total_len = 50
#   meta_filepath = ./dataset/icons_meta.csv
#   model_args = ['commands', 'args', 'commands', 'args']
#   model_cfg = <configs.deepsvg.hierarchical_ordered.ModelConfig object at 0x7fcb752c2650>
#   n_recon_points = 20
#   nb_augmentations = 1
#   num_epochs = 100
#   num_gpus = 2
#   num_steps = None
#   optimizer_starts = [0]
#   pretrained_path = None
#   stats_to_print = {'train': ['lr', 'time'], 'valid': []}
#   train_ratio = 0.9
#   val_every = 1000
#   warmup_steps = 500
# Model loaded

# %%
from deepsvg.train import _batch_reconstruction_loss_for_svg_sampled_points
from deepsvg.difflib.loss import svg_emd_loss
from deepsvg.difflib.loss import chamfer_loss

N_POINTS = 10
cfg.n_recon_points = N_POINTS
cfg.loss_recon_fn_dict = {"loss_re": chamfer_loss, "loss_emd": svg_emd_loss}

batch = next(iter(dataloader))
print("COMPUTING THE LOSSES")
_batch_reconstruction_loss_for_svg_sampled_points(model, cfg, batch, show_logs=True)
# Out:
# COMPUTING THE LOSSES
# Reconstruction losses
# LOSS 0000 loss_re:	0.008892061188817024
# LOSS 0000 loss_emd:	0.0728403776884079
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0001 loss_re:	0.013874095864593983
# LOSS 0001 loss_emd:	0.0516645684838295
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0002 loss_re:	0.014716213569045067
# LOSS 0002 loss_emd:	0.15144029259681702
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0003 loss_re:	0.01196841336786747
# LOSS 0003 loss_emd:	0.17270101606845856
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0004 loss_re:	0.015198057517409325
# LOSS 0004 loss_emd:	0.057208120822906494
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0005 loss_re:	0.011411748826503754
# LOSS 0005 loss_emd:	0.050065018236637115
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0006 loss_re:	0.017103880643844604
# LOSS 0006 loss_emd:	0.1453518569469452
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0007 loss_re:	0.01854337938129902
# LOSS 0007 loss_emd:	0.1061277985572815
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0008 loss_re:	0.008504506200551987
# LOSS 0008 loss_emd:	0.05850999057292938
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0009 loss_re:	0.015991803258657455
# LOSS 0009 loss_emd:	0.19923509657382965
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0010 loss_re:	0.009437872096896172
# LOSS 0010 loss_emd:	0.12472214549779892
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0011 loss_re:	0.01427982933819294
# LOSS 0011 loss_emd:	0.09545326977968216
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0012 loss_re:	0.00880349799990654
# LOSS 0012 loss_emd:	0.08175012469291687
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0013 loss_re:	0.011300446465611458
# LOSS 0013 loss_emd:	0.07658476382493973
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0014 loss_re:	0.009602786973118782
# LOSS 0014 loss_emd:	0.09988860785961151
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0015 loss_re:	0.011854485608637333
# LOSS 0015 loss_emd:	0.14336518943309784
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0016 loss_re:	0.023751433938741684
# LOSS 0016 loss_emd:	0.08648938685655594
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0017 loss_re:	0.007175709120929241
# LOSS 0017 loss_emd:	0.1254020780324936
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0018 loss_re:	0.01578805036842823
# LOSS 0018 loss_emd:	0.11994551867246628
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0019 loss_re:	0.012190240435302258
# LOSS 0019 loss_emd:	0.10208029299974442
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0020 loss_re:	0.009790714830160141
# LOSS 0020 loss_emd:	0.22238680720329285
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0021 loss_re:	0.013338606804609299
# LOSS 0021 loss_emd:	0.07428324222564697
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0022 loss_re:	0.010766969062387943
# LOSS 0022 loss_emd:	0.05158060044050217
# TARGET vs PREDICTION
# Reconstruction losses
# LOSS 0023 loss_re:	0.009446315467357635
# LOSS 0023 loss_emd:	0.08219240605831146
# TARGET vs PREDICTION
# defaultdict(list,
#             {'loss_re': [0.008892061188817024,
#               0.013874095864593983,
#               0.014716213569045067,
#               0.01196841336786747,
#               0.015198057517409325,
#               0.011411748826503754,
#               0.017103880643844604,
#               0.01854337938129902,
#               0.008504506200551987,
#               0.015991803258657455,
#               0.009437872096896172,
#               0.01427982933819294,
#               0.00880349799990654,
#               0.011300446465611458,
#               0.009602786973118782,
#               0.011854485608637333,
#               0.023751433938741684,
#               0.007175709120929241,
#               0.01578805036842823,
#               0.012190240435302258,
#               0.009790714830160141,
#               0.013338606804609299,
#               0.010766969062387943,
#               0.009446315467357635],
#              'loss_emd': [0.0728403776884079,
#               0.0516645684838295,
#               0.15144029259681702,
#               0.17270101606845856,
#               0.057208120822906494,
#               0.050065018236637115,
#               0.1453518569469452,
#               0.1061277985572815,
#               0.05850999057292938,
#               0.19923509657382965,
#               0.12472214549779892,
#               0.09545326977968216,
#               0.08175012469291687,
#               0.07658476382493973,
#               0.09988860785961151,
#               0.14336518943309784,
#               0.08648938685655594,
#               0.1254020780324936,
#               0.11994551867246628,
#               0.10208029299974442,
#               0.22238680720329285,
#               0.07428324222564697,
#               0.05158060044050217,
#               0.08219240605831146]})
